# %% [markdown]
# # Benchmark All Algorithms
#
# This notebook sequentially trains all RL algorithms on the Chase the Dot environment for 250,000 timesteps each.
#
# > **Note:** Make sure you have at least one instance of the `Cy_RL_PS.exe` environment running on port 6102 before starting this notebook!

# %%
import os
import gc
from chase_the_dot.run import main

# Configuration
TIMESTEPS = 100000
ALGORITHMS = ["sac", "td3", "ppo", "pid"]

os.makedirs("models", exist_ok=True)
os.makedirs("runs", exist_ok=True)

# %%
for algo in ALGORITHMS:
    print(f"\n{'='*60}")
    print(f"Starting {algo.upper()} for {TIMESTEPS} timesteps...")
    print(f"{'='*60}\n")
    
    try:
        # Run natively within the notebook process
        main([
            "--algo", algo,
            "--timesteps", str(TIMESTEPS),
            "--domain-expansion"
        ])
    except KeyboardInterrupt:
        print("\nBenchmark interrupted by user.")
        break
    except Exception as e:
        print(f"\n[ERROR] Algorithm {algo.upper()} crashed: {e}")
        break
    
    # Force Python to clear the neural networks from memory before starting the next algorithm
    gc.collect()

print("\nBenchmark complete! Run `uv run tensorboard --logdir runs/` in your terminal to view results.")
# Out:
# ============================================================
# Starting SAC for 100000 timesteps...
# ============================================================
#
# Set global seed to 42
# Connecting to Chase the Dot application at 127.0.0.1:6102...
# Connected successfully! Auto-drain thread active.
# Domain Expansion active: starting at easiest config (Speed=500, Size=100.0%), expanding over 70000 steps (hard_ratio=0.5)
# Sending configuration: Speed=500, Size=100.0%
# Initializing SAC Policy (frame_stack=4, obs_dim=32)
# Starting tracking loop using SAC (Training). Press Ctrl+C to stop.
# Training SAC:   5%|▌         | 5007/100000 [02:06<38:15, 41.39step/s, cfg=sp:500|sz:100, dist=6.6, in_bounds=78%, loss=-3.87, reward=1.23]
# [5000/100000] Domain Expansion (alpha=0.07, Generalization) -> Speed=475, Size=94.2% | Unlocked: Speed in [471, 500], Size in [93.6, 100.0]
# Training SAC:  10%|█         | 10006/100000 [04:12<40:20, 37.18step/s, cfg=sp:475|sz:94, dist=9.7, in_bounds=97%, loss=-14.69, reward=1.81]
# [10000/100000] Domain Expansion (alpha=0.14, Hard Frontier) -> Speed=442, Size=87.1% | Unlocked: Speed in [442, 500], Size in [87.1, 100.0]
# Training SAC:  15%|█▌        | 15007/100000 [06:22<33:11, 42.68step/s, cfg=sp:414|sz:83, dist=7.5, in_bounds=97%, loss=-28.44, reward=1.82]
# [15000/100000] Domain Expansion (alpha=0.21, Generalization) -> Speed=414, Size=83.1% | Unlocked: Speed in [414, 500], Size in [80.7, 100.0]
# Training SAC:  20%|██        | 20006/100000 [08:29<36:13, 36.81step/s, cfg=sp:451|sz:76, dist=9.6, in_bounds=100%, loss=-39.99, reward=1.89]
# [20000/100000] Domain Expansion (alpha=0.29, Generalization) -> Speed=451, Size=75.7% | Unlocked: Speed in [385, 500], Size in [74.3, 100.0]
# Training SAC:  25%|██▌       | 25008/100000 [10:36<28:06, 44.47step/s, cfg=sp:451|sz:76, dist=8.4, in_bounds=94%, loss=-44.99, reward=1.69]
# [25000/100000] Domain Expansion (alpha=0.36, Hard Frontier) -> Speed=357, Size=67.9% | Unlocked: Speed in [357, 500], Size in [67.9, 100.0]
# Training SAC:  30%|███       | 30006/100000 [12:45<29:00, 40.21step/s, cfg=sp:357|sz:68, dist=7.1, in_bounds=97%, loss=-51.71, reward=1.80]
# [30000/100000] Domain Expansion (alpha=0.43, Generalization) -> Speed=379, Size=80.7% | Unlocked: Speed in [328, 500], Size in [61.4, 100.0]
# Training SAC:  35%|███▌      | 35007/100000 [14:51<27:23, 39.55step/s, cfg=sp:300|sz:55, dist=7.1, in_bounds=100%, loss=-57.98, reward=1.90]
# [35000/100000] Domain Expansion (alpha=0.50, Hard Frontier) -> Speed=300, Size=55.0% | Unlocked: Speed in [300, 500], Size in [55.0, 100.0]
# Training SAC:  40%|████      | 40007/100000 [16:55<25:43, 38.86step/s, cfg=sp:271|sz:49, dist=8.5, in_bounds=100%, loss=-60.83, reward=1.81]
# [40000/100000] Domain Expansion (alpha=0.57, Hard Frontier) -> Speed=271, Size=48.6% | Unlocked: Speed in [271, 500], Size in [48.6, 100.0]
# Training SAC:  45%|████▌     | 45007/100000 [19:01<23:36, 38.83step/s, cfg=sp:271|sz:49, dist=8.5, in_bounds=100%, loss=-63.73, reward=1.76]
# [45000/100000] Domain Expansion (alpha=0.64, Generalization) -> Speed=413, Size=42.2% | Unlocked: Speed in [242, 500], Size in [42.1, 100.0]
# Training SAC:  50%|█████     | 50008/100000 [21:08<18:34, 44.84step/s, cfg=sp:413|sz:42, dist=10.3, in_bounds=53%, loss=-63.33, reward=-0.01]
# [50000/100000] Domain Expansion (alpha=0.71, Hard Frontier) -> Speed=214, Size=35.7% | Unlocked: Speed in [214, 500], Size in [35.7, 100.0]
# Training SAC:  55%|█████▌    | 55007/100000 [23:17<18:25, 40.68step/s, cfg=sp:292|sz:82, dist=8.7, in_bounds=100%, loss=-65.22, reward=1.70]
# [55000/100000] Domain Expansion (alpha=0.79, Generalization) -> Speed=292, Size=82.1% | Unlocked: Speed in [185, 500], Size in [29.3, 100.0]
# Training SAC:  60%|██████    | 60010/100000 [25:29<15:01, 44.38step/s, cfg=sp:157|sz:23, dist=12.3, in_bounds=100%, loss=-64.53, reward=1.83]
# [60000/100000] Domain Expansion (alpha=0.86, Hard Frontier) -> Speed=157, Size=22.9% | Unlocked: Speed in [157, 500], Size in [22.9, 100.0]
# Training SAC:  65%|██████▌   | 65006/100000 [27:34<15:12, 38.35step/s, cfg=sp:157|sz:23, dist=6.0, in_bounds=100%, loss=-65.24, reward=1.57]
# [65000/100000] Domain Expansion (alpha=0.93, Hard Frontier) -> Speed=128, Size=16.4% | Unlocked: Speed in [128, 500], Size in [16.4, 100.0]
# Training SAC:  70%|███████   | 70005/100000 [29:40<12:12, 40.94step/s, cfg=sp:128|sz:16, dist=19.1, in_bounds=100%, loss=-64.42, reward=1.15]
# [70000/100000] Domain Expansion (alpha=1.00, Generalization) -> Speed=496, Size=82.7% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training SAC:  75%|███████▌  | 75007/100000 [31:49<10:07, 41.13step/s, cfg=sp:434|sz:28, dist=7.6, in_bounds=66%, loss=-64.32, reward=0.60]
# [75000/100000] Domain Expansion (alpha=1.00, Generalization) -> Speed=434, Size=27.5% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training SAC:  80%|████████  | 80006/100000 [33:54<08:22, 39.78step/s, cfg=sp:100|sz:10, dist=32.6, in_bounds=9%, loss=-48.77, reward=-2.46]
# [80000/100000] Domain Expansion (alpha=1.00, Hard Frontier) -> Speed=100, Size=10.0% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training SAC:  85%|████████▌ | 85005/100000 [36:01<05:38, 44.26step/s, cfg=sp:100|sz:10, dist=7.3, in_bounds=100%, loss=-57.09, reward=1.12]
# [85000/100000] Domain Expansion (alpha=1.00, Generalization) -> Speed=193, Size=37.4% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training SAC:  90%|█████████ | 90009/100000 [38:06<03:47, 43.85step/s, cfg=sp:193|sz:37, dist=12.3, in_bounds=100%, loss=-56.56, reward=1.45]
# [90000/100000] Domain Expansion (alpha=1.00, Hard Frontier) -> Speed=100, Size=10.0% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training SAC:  95%|█████████▌| 95007/100000 [40:11<02:16, 36.71step/s, cfg=sp:100|sz:10, dist=30.0, in_bounds=97%, loss=-55.54, reward=0.13]
# [95000/100000] Domain Expansion (alpha=1.00, Hard Frontier) -> Speed=100, Size=10.0% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training SAC: 100%|██████████| 100000/100000 [42:15<00:00, 39.43step/s, cfg=sp:194|sz:29, dist=7.5, in_bounds=100%, loss=-53.46, reward=1.16]
# [100000/100000] Domain Expansion (alpha=1.00, Generalization) -> Speed=194, Size=28.9% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Disconnected cleanly.
#
# ============================================================
# Starting TD3 for 100000 timesteps...
# ============================================================
#
# Set global seed to 42
# Connecting to Chase the Dot application at 127.0.0.1:6102...
# Connected successfully! Auto-drain thread active.
# Domain Expansion active: starting at easiest config (Speed=500, Size=100.0%), expanding over 70000 steps (hard_ratio=0.5)
# Sending configuration: Speed=500, Size=100.0%
# Initializing TD3 Policy (frame_stack=4, obs_dim=32)
# Starting tracking loop using TD3 (Training). Press Ctrl+C to stop.
# Training TD3:   5%|▌         | 5007/100000 [02:09<40:38, 38.95step/s, cfg=sp:500|sz:100, dist=9.5, in_bounds=62%, loss=0.23, reward=0.64]
# [5000/100000] Domain Expansion (alpha=0.07, Generalization) -> Speed=475, Size=94.2% | Unlocked: Speed in [471, 500], Size in [93.6, 100.0]
# Training TD3:  10%|█         | 10005/100000 [04:20<40:00, 37.49step/s, cfg=sp:475|sz:94, dist=11.2, in_bounds=56%, loss=29.08, reward=0.35]
# [10000/100000] Domain Expansion (alpha=0.14, Hard Frontier) -> Speed=442, Size=87.1% | Unlocked: Speed in [442, 500], Size in [87.1, 100.0]
# Training TD3:  15%|█▌        | 15006/100000 [06:33<39:03, 36.27step/s, cfg=sp:442|sz:87, dist=12.0, in_bounds=84%, loss=-9.75, reward=1.27]
# [15000/100000] Domain Expansion (alpha=0.21, Generalization) -> Speed=414, Size=83.1% | Unlocked: Speed in [414, 500], Size in [80.7, 100.0]
# Training TD3:  20%|██        | 20007/100000 [08:49<33:29, 39.80step/s, cfg=sp:451|sz:76, dist=12.2, in_bounds=88%, loss=-14.13, reward=1.40]
# [20000/100000] Domain Expansion (alpha=0.29, Generalization) -> Speed=451, Size=75.7% | Unlocked: Speed in [385, 500], Size in [74.3, 100.0]
# Training TD3:  25%|██▌       | 25006/100000 [11:03<35:21, 35.34step/s, cfg=sp:451|sz:76, dist=51.1, in_bounds=69%, loss=-19.27, reward=-0.12]
# [25000/100000] Domain Expansion (alpha=0.36, Hard Frontier) -> Speed=357, Size=67.9% | Unlocked: Speed in [357, 500], Size in [67.9, 100.0]
# Training TD3:  30%|███       | 30003/100000 [13:15<31:47, 36.70step/s, cfg=sp:357|sz:68, dist=36.5, in_bounds=100%, loss=-21.28, reward=1.72]
# [30000/100000] Domain Expansion (alpha=0.43, Generalization) -> Speed=379, Size=80.7% | Unlocked: Speed in [328, 500], Size in [61.4, 100.0]
# Training TD3:  35%|███▌      | 35007/100000 [15:30<30:13, 35.85step/s, cfg=sp:379|sz:81, dist=10.9, in_bounds=97%, loss=-27.77, reward=1.74]
# [35000/100000] Domain Expansion (alpha=0.50, Hard Frontier) -> Speed=300, Size=55.0% | Unlocked: Speed in [300, 500], Size in [55.0, 100.0]
# Training TD3:  40%|████      | 40006/100000 [17:43<24:59, 40.00step/s, cfg=sp:271|sz:49, dist=11.1, in_bounds=100%, loss=34.18, reward=1.70]
# [40000/100000] Domain Expansion (alpha=0.57, Hard Frontier) -> Speed=271, Size=48.6% | Unlocked: Speed in [271, 500], Size in [48.6, 100.0]
# Training TD3:  45%|████▌     | 45006/100000 [20:00<27:37, 33.17step/s, cfg=sp:271|sz:49, dist=11.8, in_bounds=100%, loss=-33.38, reward=1.62]
# [45000/100000] Domain Expansion (alpha=0.64, Generalization) -> Speed=413, Size=42.2% | Unlocked: Speed in [242, 500], Size in [42.1, 100.0]
# Training TD3:  50%|█████     | 50004/100000 [22:12<23:45, 35.08step/s, cfg=sp:413|sz:42, dist=9.5, in_bounds=72%, loss=-39.03, reward=0.81]
# [50000/100000] Domain Expansion (alpha=0.71, Hard Frontier) -> Speed=214, Size=35.7% | Unlocked: Speed in [214, 500], Size in [35.7, 100.0]
# Training TD3:  55%|█████▌    | 55006/100000 [24:27<22:06, 33.92step/s, cfg=sp:214|sz:36, dist=8.8, in_bounds=97%, loss=-39.85, reward=1.53]
# [55000/100000] Domain Expansion (alpha=0.79, Generalization) -> Speed=292, Size=82.1% | Unlocked: Speed in [185, 500], Size in [29.3, 100.0]
# Training TD3:  60%|██████    | 60006/100000 [26:39<18:45, 35.53step/s, cfg=sp:157|sz:23, dist=8.8, in_bounds=100%, loss=-41.77, reward=1.90]
# [60000/100000] Domain Expansion (alpha=0.86, Hard Frontier) -> Speed=157, Size=22.9% | Unlocked: Speed in [157, 500], Size in [22.9, 100.0]
# Training TD3:  65%|██████▌   | 65006/100000 [28:55<12:47, 45.61step/s, cfg=sp:157|sz:23, dist=6.2, in_bounds=100%, loss=-44.26, reward=1.57]
# [65000/100000] Domain Expansion (alpha=0.93, Hard Frontier) -> Speed=128, Size=16.4% | Unlocked: Speed in [128, 500], Size in [16.4, 100.0]
# Training TD3:  70%|███████   | 70006/100000 [31:10<13:29, 37.04step/s, cfg=sp:128|sz:16, dist=37.1, in_bounds=100%, loss=-46.08, reward=1.38]
# [70000/100000] Domain Expansion (alpha=1.00, Generalization) -> Speed=496, Size=82.7% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training TD3:  75%|███████▌  | 75007/100000 [33:21<09:43, 42.80step/s, cfg=sp:434|sz:28, dist=10.6, in_bounds=44%, loss=-49.22, reward=-0.30]
# [75000/100000] Domain Expansion (alpha=1.00, Generalization) -> Speed=434, Size=27.5% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training TD3:  80%|████████  | 80007/100000 [35:36<09:11, 36.28step/s, cfg=sp:100|sz:10, dist=9.6, in_bounds=31%, loss=-48.42, reward=-0.76]
# [80000/100000] Domain Expansion (alpha=1.00, Hard Frontier) -> Speed=100, Size=10.0% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training TD3:  85%|████████▌ | 85005/100000 [37:52<07:23, 33.84step/s, cfg=sp:100|sz:10, dist=6.4, in_bounds=100%, loss=-45.63, reward=1.21]
# [85000/100000] Domain Expansion (alpha=1.00, Generalization) -> Speed=193, Size=37.4% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training TD3:  90%|█████████ | 90008/100000 [40:08<03:37, 46.04step/s, cfg=sp:193|sz:37, dist=35.9, in_bounds=97%, loss=-48.11, reward=0.44]
# [90000/100000] Domain Expansion (alpha=1.00, Hard Frontier) -> Speed=100, Size=10.0% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training TD3:  95%|█████████▌| 95007/100000 [42:22<02:14, 37.09step/s, cfg=sp:100|sz:10, dist=6.9, in_bounds=100%, loss=-45.25, reward=1.35]
# [95000/100000] Domain Expansion (alpha=1.00, Hard Frontier) -> Speed=100, Size=10.0% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training TD3: 100%|██████████| 100000/100000 [44:37<00:00, 37.34step/s, cfg=sp:194|sz:29, dist=7.1, in_bounds=100%, loss=-45.99, reward=1.30]
# [100000/100000] Domain Expansion (alpha=1.00, Generalization) -> Speed=194, Size=28.9% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Disconnected cleanly.
#
# ============================================================
# Starting PPO for 100000 timesteps...
# ============================================================
#
# Set global seed to 42
# Connecting to Chase the Dot application at 127.0.0.1:6102...
# Connected successfully! Auto-drain thread active.
# Domain Expansion active: starting at easiest config (Speed=500, Size=100.0%), expanding over 70000 steps (hard_ratio=0.5)
# Sending configuration: Speed=500, Size=100.0%
# Initializing PPO Policy (frame_stack=4, obs_dim=32)
# Starting tracking loop using PPO (Training). Press Ctrl+C to stop.
# Training PPO:   5%|▌         | 5008/100000 [02:22<34:16, 46.20step/s, cfg=sp:500|sz:100, dist=9.4, in_bounds=57%, loss=60.04, reward=0.45]
# [5000/100000] Domain Expansion (alpha=0.07, Generalization) -> Speed=471, Size=98.3% | Unlocked: Speed in [471, 500], Size in [93.6, 100.0]
# Training PPO:  10%|█         | 10004/100000 [04:44<37:01, 40.51step/s, cfg=sp:471|sz:98, dist=14.2, in_bounds=54%, loss=347.26, reward=0.21]
# [10000/100000] Domain Expansion (alpha=0.14, Hard Frontier) -> Speed=442, Size=87.1% | Unlocked: Speed in [442, 500], Size in [87.1, 100.0]
# Training PPO:  15%|█▌        | 15007/100000 [07:05<40:10, 35.25step/s, cfg=sp:442|sz:87, dist=13.2, in_bounds=58%, loss=252.62, reward=0.23]
# [15000/100000] Domain Expansion (alpha=0.21, Hard Frontier) -> Speed=414, Size=80.7% | Unlocked: Speed in [414, 500], Size in [80.7, 100.0]
# Training PPO:  20%|██        | 20008/100000 [09:27<34:10, 39.01step/s, cfg=sp:414|sz:81, dist=12.4, in_bounds=79%, loss=231.91, reward=1.12]
# [20000/100000] Domain Expansion (alpha=0.29, Hard Frontier) -> Speed=385, Size=74.3% | Unlocked: Speed in [385, 500], Size in [74.3, 100.0]
# Training PPO:  25%|██▌       | 25007/100000 [11:49<34:52, 35.85step/s, cfg=sp:385|sz:74, dist=16.5, in_bounds=95%, loss=217.20, reward=1.53]
# [25000/100000] Domain Expansion (alpha=0.36, Generalization) -> Speed=496, Size=70.7% | Unlocked: Speed in [357, 500], Size in [67.9, 100.0]
# Training PPO:  30%|███       | 30006/100000 [14:11<34:38, 33.67step/s, cfg=sp:496|sz:71, dist=8.9, in_bounds=40%, loss=95.75, reward=-0.30]
# [30000/100000] Domain Expansion (alpha=0.43, Hard Frontier) -> Speed=328, Size=61.4% | Unlocked: Speed in [328, 500], Size in [61.4, 100.0]
# Training PPO:  35%|███▌      | 35005/100000 [16:32<29:44, 36.42step/s, cfg=sp:328|sz:61, dist=9.2, in_bounds=100%, loss=197.00, reward=1.78]
# [35000/100000] Domain Expansion (alpha=0.50, Hard Frontier) -> Speed=300, Size=55.0% | Unlocked: Speed in [300, 500], Size in [55.0, 100.0]
# Training PPO:  40%|████      | 40008/100000 [18:53<23:40, 42.23step/s, cfg=sp:300|sz:55, dist=11.2, in_bounds=99%, loss=124.32, reward=1.67]
# [40000/100000] Domain Expansion (alpha=0.57, Hard Frontier) -> Speed=271, Size=48.6% | Unlocked: Speed in [271, 500], Size in [48.6, 100.0]
# Training PPO:  45%|████▌     | 45005/100000 [21:14<27:32, 33.28step/s, cfg=sp:271|sz:49, dist=13.9, in_bounds=100%, loss=325.80, reward=1.64]
# [45000/100000] Domain Expansion (alpha=0.64, Generalization) -> Speed=255, Size=74.6% | Unlocked: Speed in [242, 500], Size in [42.1, 100.0]
# Training PPO:  50%|█████     | 50008/100000 [23:36<20:42, 40.23step/s, cfg=sp:255|sz:75, dist=12.3, in_bounds=100%, loss=229.26, reward=1.83]
# [50000/100000] Domain Expansion (alpha=0.71, Generalization) -> Speed=493, Size=62.7% | Unlocked: Speed in [214, 500], Size in [35.7, 100.0]
# Training PPO:  55%|█████▌    | 55006/100000 [25:57<20:13, 37.08step/s, cfg=sp:493|sz:63, dist=9.8, in_bounds=41%, loss=32.10, reward=-0.22]
# [55000/100000] Domain Expansion (alpha=0.79, Hard Frontier) -> Speed=185, Size=29.3% | Unlocked: Speed in [185, 500], Size in [29.3, 100.0]
# Training PPO:  60%|██████    | 60006/100000 [28:19<17:22, 38.37step/s, cfg=sp:185|sz:29, dist=10.6, in_bounds=100%, loss=277.01, reward=1.58]
# [60000/100000] Domain Expansion (alpha=0.86, Hard Frontier) -> Speed=157, Size=22.9% | Unlocked: Speed in [157, 500], Size in [22.9, 100.0]
# Training PPO:  65%|██████▌   | 65007/100000 [30:41<14:36, 39.91step/s, cfg=sp:157|sz:23, dist=8.5, in_bounds=100%, loss=118.70, reward=1.66]
# [65000/100000] Domain Expansion (alpha=0.93, Generalization) -> Speed=209, Size=74.8% | Unlocked: Speed in [128, 500], Size in [16.4, 100.0]
# Training PPO:  70%|███████   | 70007/100000 [33:03<13:48, 36.22step/s, cfg=sp:209|sz:75, dist=10.2, in_bounds=100%, loss=367.36, reward=1.86]
# [70000/100000] Domain Expansion (alpha=1.00, Hard Frontier) -> Speed=100, Size=10.0% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training PPO:  75%|███████▌  | 75005/100000 [35:24<10:45, 38.72step/s, cfg=sp:100|sz:10, dist=7.8, in_bounds=100%, loss=139.87, reward=1.27]
# [75000/100000] Domain Expansion (alpha=1.00, Hard Frontier) -> Speed=100, Size=10.0% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training PPO:  80%|████████  | 80003/100000 [37:47<10:08, 32.85step/s, cfg=sp:100|sz:10, dist=5.2, in_bounds=100%, loss=151.33, reward=1.47]
# [80000/100000] Domain Expansion (alpha=1.00, Generalization) -> Speed=272, Size=19.2% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training PPO:  85%|████████▌ | 85007/100000 [40:09<06:56, 36.03step/s, cfg=sp:272|sz:19, dist=4.6, in_bounds=100%, loss=148.92, reward=1.62]
# [85000/100000] Domain Expansion (alpha=1.00, Hard Frontier) -> Speed=100, Size=10.0% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training PPO:  90%|█████████ | 90007/100000 [42:29<04:49, 34.54step/s, cfg=sp:100|sz:10, dist=8.5, in_bounds=100%, loss=79.13, reward=1.16]
# [90000/100000] Domain Expansion (alpha=1.00, Hard Frontier) -> Speed=100, Size=10.0% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training PPO:  95%|█████████▌| 95005/100000 [44:50<02:20, 35.67step/s, cfg=sp:100|sz:10, dist=7.6, in_bounds=100%, loss=122.91, reward=1.39]
# [95000/100000] Domain Expansion (alpha=1.00, Hard Frontier) -> Speed=100, Size=10.0% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training PPO: 100%|██████████| 100000/100000 [47:11<00:00, 35.31step/s, cfg=sp:100|sz:10, dist=8.5, in_bounds=100%, loss=94.36, reward=1.24]
# [100000/100000] Domain Expansion (alpha=1.00, Hard Frontier) -> Speed=100, Size=10.0% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Disconnected cleanly.
#
# ============================================================
# Starting PID for 100000 timesteps...
# ============================================================
#
# Set global seed to 42
# Connecting to Chase the Dot application at 127.0.0.1:6102...
# Connected successfully! Auto-drain thread active.
# Domain Expansion active: starting at easiest config (Speed=500, Size=100.0%), expanding over 70000 steps (hard_ratio=0.5)
# Sending configuration: Speed=500, Size=100.0%
# Initializing PID Policy (kp=0.4, ki=0.02, kd=0.1)
# Starting tracking loop using PID (Training). Press Ctrl+C to stop.
# Training PID:   5%|▌         | 5006/100000 [02:21<43:07, 36.71step/s, cfg=sp:500|sz:100, dist=6.2, in_bounds=100%, loss=0.00, reward=1.97]
# [5000/100000] Domain Expansion (alpha=0.07, Generalization) -> Speed=471, Size=98.3% | Unlocked: Speed in [471, 500], Size in [93.6, 100.0]
# Training PID:  10%|█         | 10007/100000 [04:42<39:53, 37.59step/s, cfg=sp:471|sz:98, dist=12.0, in_bounds=41%, loss=0.00, reward=-0.15]
# [10000/100000] Domain Expansion (alpha=0.14, Hard Frontier) -> Speed=442, Size=87.1% | Unlocked: Speed in [442, 500], Size in [87.1, 100.0]
# Training PID:  15%|█▌        | 15007/100000 [07:05<33:55, 41.76step/s, cfg=sp:414|sz:81, dist=4.1, in_bounds=100%, loss=0.00, reward=1.98]
# [15000/100000] Domain Expansion (alpha=0.21, Hard Frontier) -> Speed=414, Size=80.7% | Unlocked: Speed in [414, 500], Size in [80.7, 100.0]
# Training PID:  20%|██        | 20004/100000 [09:27<37:25, 35.62step/s, cfg=sp:385|sz:74, dist=2.1, in_bounds=100%, loss=0.00, reward=1.99]
# [20000/100000] Domain Expansion (alpha=0.29, Hard Frontier) -> Speed=385, Size=74.3% | Unlocked: Speed in [385, 500], Size in [74.3, 100.0]
# Training PID:  25%|██▌       | 25007/100000 [11:50<35:29, 35.21step/s, cfg=sp:385|sz:74, dist=18.2, in_bounds=53%, loss=0.00, reward=0.04]
# [25000/100000] Domain Expansion (alpha=0.36, Generalization) -> Speed=496, Size=70.7% | Unlocked: Speed in [357, 500], Size in [67.9, 100.0]
# Training PID:  30%|███       | 30007/100000 [14:12<32:16, 36.14step/s, cfg=sp:496|sz:71, dist=21.4, in_bounds=0%, loss=0.00, reward=-2.76]
# [30000/100000] Domain Expansion (alpha=0.43, Hard Frontier) -> Speed=328, Size=61.4% | Unlocked: Speed in [328, 500], Size in [61.4, 100.0]
# Training PID:  35%|███▌      | 35007/100000 [16:36<29:42, 36.47step/s, cfg=sp:300|sz:55, dist=12.5, in_bounds=81%, loss=0.00, reward=1.10]
# [35000/100000] Domain Expansion (alpha=0.50, Hard Frontier) -> Speed=300, Size=55.0% | Unlocked: Speed in [300, 500], Size in [55.0, 100.0]
# Training PID:  40%|████      | 40005/100000 [18:58<26:19, 37.97step/s, cfg=sp:271|sz:49, dist=7.6, in_bounds=100%, loss=0.00, reward=1.85]
# [40000/100000] Domain Expansion (alpha=0.57, Hard Frontier) -> Speed=271, Size=48.6% | Unlocked: Speed in [271, 500], Size in [48.6, 100.0]
# Training PID:  45%|████▌     | 45006/100000 [21:22<26:39, 34.39step/s, cfg=sp:271|sz:49, dist=6.7, in_bounds=100%, loss=0.00, reward=1.85]
# [45000/100000] Domain Expansion (alpha=0.64, Generalization) -> Speed=255, Size=74.6% | Unlocked: Speed in [242, 500], Size in [42.1, 100.0]
# Training PID:  50%|█████     | 50005/100000 [23:46<21:04, 39.53step/s, cfg=sp:255|sz:75, dist=18.6, in_bounds=100%, loss=0.00, reward=1.61]
# [50000/100000] Domain Expansion (alpha=0.71, Generalization) -> Speed=493, Size=62.7% | Unlocked: Speed in [214, 500], Size in [35.7, 100.0]
# Training PID:  55%|█████▌    | 55007/100000 [26:08<20:23, 36.78step/s, cfg=sp:185|sz:29, dist=5.9, in_bounds=41%, loss=0.00, reward=-0.08]
# [55000/100000] Domain Expansion (alpha=0.79, Hard Frontier) -> Speed=185, Size=29.3% | Unlocked: Speed in [185, 500], Size in [29.3, 100.0]
# Training PID:  60%|██████    | 60006/100000 [28:29<16:47, 39.68step/s, cfg=sp:157|sz:23, dist=10.8, in_bounds=100%, loss=0.00, reward=1.34]
# [60000/100000] Domain Expansion (alpha=0.86, Hard Frontier) -> Speed=157, Size=22.9% | Unlocked: Speed in [157, 500], Size in [22.9, 100.0]
# Training PID:  65%|██████▌   | 65004/100000 [30:54<17:32, 33.25step/s, cfg=sp:157|sz:23, dist=4.5, in_bounds=100%, loss=0.00, reward=1.73]
# [65000/100000] Domain Expansion (alpha=0.93, Generalization) -> Speed=209, Size=74.8% | Unlocked: Speed in [128, 500], Size in [16.4, 100.0]
# Training PID:  70%|███████   | 70004/100000 [33:17<13:39, 36.62step/s, cfg=sp:209|sz:75, dist=7.4, in_bounds=100%, loss=0.00, reward=1.92]
# [70000/100000] Domain Expansion (alpha=1.00, Hard Frontier) -> Speed=100, Size=10.0% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training PID:  75%|███████▌  | 75007/100000 [35:38<11:31, 36.12step/s, cfg=sp:100|sz:10, dist=4.6, in_bounds=100%, loss=0.00, reward=1.29]
# [75000/100000] Domain Expansion (alpha=1.00, Hard Frontier) -> Speed=100, Size=10.0% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training PID:  80%|████████  | 80007/100000 [38:00<08:50, 37.70step/s, cfg=sp:272|sz:19, dist=7.3, in_bounds=100%, loss=0.00, reward=1.11]
# [80000/100000] Domain Expansion (alpha=1.00, Generalization) -> Speed=272, Size=19.2% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training PID:  85%|████████▌ | 85007/100000 [40:23<06:56, 36.00step/s, cfg=sp:272|sz:19, dist=6.7, in_bounds=100%, loss=0.00, reward=1.38]
# [85000/100000] Domain Expansion (alpha=1.00, Hard Frontier) -> Speed=100, Size=10.0% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training PID:  90%|█████████ | 90005/100000 [42:44<05:09, 32.34step/s, cfg=sp:100|sz:10, dist=1.8, in_bounds=100%, loss=0.00, reward=1.76]
# [90000/100000] Domain Expansion (alpha=1.00, Hard Frontier) -> Speed=100, Size=10.0% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training PID:  95%|█████████▌| 95007/100000 [45:06<02:15, 36.72step/s, cfg=sp:100|sz:10, dist=5.5, in_bounds=100%, loss=0.00, reward=1.12]
# [95000/100000] Domain Expansion (alpha=1.00, Hard Frontier) -> Speed=100, Size=10.0% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Training PID: 100%|██████████| 100000/100000 [47:28<00:00, 35.10step/s, cfg=sp:100|sz:10, dist=2.2, in_bounds=100%, loss=0.00, reward=1.67]
# [100000/100000] Domain Expansion (alpha=1.00, Hard Frontier) -> Speed=100, Size=10.0% | Unlocked: Speed in [100, 500], Size in [10.0, 100.0]
# Disconnected cleanly.
#
# Benchmark complete! Run `uv run tensorboard --logdir runs/` in your terminal to view results.
